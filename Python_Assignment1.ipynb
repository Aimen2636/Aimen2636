# %% [markdown]
# <a href="https://colab.research.google.com/github/Aimen2636/Aimen2636/blob/main/Python_Assignment1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Python Assignment 1: Variables and Data Types
# Name: Aimen Ejaz Kiani

# Q1. Variable: A container for storing data values.
name = "Aimen"
print(name)

# Q2. Rules: Must start with letter/_ and cannot start with a number.
my_var = 10  # Correct

# Q3. Integer: Whole numbers without decimals.
age = 25
print(type(age))

# Q4. Float: Numbers with decimal points.
price = 99.99
print(type(price))

# Q5. String: Text surrounded by quotes.
city = "Islamabad"
print(type(city))

# Q6. Boolean: Logical values True or False.
is_valid = True
print(type(is_valid))

# Q7. type() Function: Returns the data type of a variable.
x = 50
print(type(x))

# Q8. input() Function: Used to take user input (default is string).
# user_val = input("Enter something: ")

# Q9. Type Casting: Converting one data type to another.
num_str = "100"
num_int = int(num_str)
print(num_int)

# Q10. Program: Take number and print its data type.
val = input("Enter a number: ")
print("Data type is:", type(val))
# Out:
# Aimen
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>
# <class 'int'>
# 100
# Enter a number: 23
# Data type is: <class 'str'>
